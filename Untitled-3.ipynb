# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
from datetime import datetime
import uuid

# %%
# Connect to SQLite database
conn = sqlite3.connect('torqdata.db')  # Adjust path to your database

# Load data into pandas DataFrame
query = "SELECT * FROM torqlogs where fileid=438"
df = pd.read_sql_query(query, conn)

# Close connection
conn.close()
df.size
# Out:
# 56240

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 703 entries, 0 to 702
# Data columns (total 80 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   id                                                703 non-null    int64
#  1   fileid                                            703 non-null    int64
#  2   Miles_Per_GallonLong_Term_Averagempg              703 non-null    float64
#  3   O2_Sensor1_Wide_Range_VoltageV                    0 non-null      object
#  4   Kilometers_Per_LitreLong_Term_Averagekpl          703 non-null    float64
#  5   Speed_OBDkmh                                      703 non-null    float64
#  6   CO₂_in_gkm_Averagegkm                             650 non-null    float64
#  7   Kilometers_Per_LitreInstantkpl                    702 non-null    float64
#  8   Bearing                                           703 non-null    float64
#  9   Actual_engine__torque                             0 non-null      object
#  10  GPS_Bearing                                       703 non-null    float64
#  11  Acceleration_SensorZ_axisg                        703 non-null    float64
#  12  Intake_Air_TemperatureC                           702 non-null    float64
#  13  Fuel_Remaining_Calculated_from_vehicle_profile    699 non-null    float64
#  14  Distance_travelled_with_MILCEL_litkm              700 non-null    float64
#  15  Engine_Coolant_TemperatureC                       702 non-null    float64
#  16  Acceleration_SensorX_axisg                        703 non-null    float64
#  17  Trip_TimeSince_journey_starts                     703 non-null    float64
#  18  Trip_average_MPGmpg                               683 non-null    float64
#  19  Mass_Air_Flow_Rategs                              702 non-null    float64
#  20  Device_Time                                       703 non-null    object
#  21  Fuel_flow_rateminuteccmin                         698 non-null    float64
#  22  O2_Bank_1_Sensor_1_Wide_Range_VoltageV            700 non-null    float64
#  23  Average_trip_speedwhilst_stopped_or_movingkmh     702 non-null    float64
#  24  Gx                                                703 non-null    float64
#  25  Trip_average_Litres100_KMl100km                   683 non-null    float64
#  26  Cost_per_milekm_Tripkm                            683 non-null    float64
#  27  Longitude                                         703 non-null    float64
#  28  GPS_Longitude                                     703 non-null    float64
#  29  Barometric_pressure_from_vehiclepsi               701 non-null    float64
#  30  Cost_per_milekm_Instantkm                         632 non-null    float64
#  31  O2_Sensor1_Wide_Range_Equivalence_Ratioλ          0 non-null      object
#  32  Fuel_used_tripl                                   699 non-null    float64
#  33  Engine_RPMrpm                                     701 non-null    float64
#  34  GPS_Accuracym                                     703 non-null    float64
#  35  TorqueNm                                          322 non-null    float64
#  36  Altitude                                          703 non-null    float64
#  37  GPS_Satellites                                    703 non-null    int64
#  38  GPS_Time                                          703 non-null    object
#  39  Trip_Distancekm                                   683 non-null    float64
#  40  Trip_distance_stored_in_vehicle_profilekm         703 non-null    float64
#  41  Positive_Kinetic_Energy_PKEkmhr²                  683 non-null    float64
#  42  Gcalibrated                                       703 non-null    float64
#  43  Turbo_Boost__Vacuum_Gaugepsi                      702 non-null    float64
#  44  GPS_Latitude                                      703 non-null    float64
#  45  Voltage_OBD_AdapterV                              701 non-null    float64
#  46  Speed_GPSkmh                                      703 non-null    float64
#  47  GPS_vs_OBD_Speed_differencekmh                    702 non-null    float64
#  48  Trip_timewhilst_movings                           703 non-null    float64
#  49  Engine_Load                                       701 non-null    float64
#  50  Miles_Per_GallonInstantmpg                        702 non-null    float64
#  51  Latitude                                          703 non-null    float64
#  52  Trip_timewhilst_stationarys                       703 non-null    float64
#  53  Gy                                                703 non-null    float64
#  54  Ambient_air_tempC                                 702 non-null    float64
#  55  Air_Fuel_RatioMeasured1                           700 non-null    float64
#  56  O2_Sensor1_Wide_Range_CurrentmA                   700 non-null    float64
#  57  Acceleration_SensorY_axisg                        703 non-null    float64
#  58  Horizontal_Dilution_of_Precision                  703 non-null    float64
#  59  Fuel_Rail_Pressurepsi                             701 non-null    float64
#  60  GPS_Speed_Meterssecond                            703 non-null    float64
#  61  Horsepower_At_the_wheelshp                        322 non-null    float64
#  62  Intake_Manifold_Pressurepsi                       702 non-null    float64
#  63  Average_trip_speedwhilst_moving_onlykmh           684 non-null    float64
#  64  CO₂_in_gkm_Instantaneousgkm                       576 non-null    float64
#  65  Throttle_PositionManifold                         701 non-null    float64
#  66  Volumetric_Efficiency_Calculated                  699 non-null    float64
#  67  O2_Bank_1_Sensor_1_Wide_Range_Equivalence_Ratioλ  700 non-null    float64
#  68  GPS_Altitudem                                     703 non-null    float64
#  69  Acceleration_SensorTotalg                         703 non-null    float64
#  70  Engine_kW_At_the_wheelskW                         322 non-null    float64
#  71  Trip_average_KPLkpl                               683 non-null    float64
#  72  Fuel_cost_tripcost                                699 non-null    float64
#  73  Distance_to_empty_Estimatedkm                     699 non-null    float64
#  74  Fuel_flow_ratehourlhr                             698 non-null    float64
#  75  Litres_Per_100_KilometerInstantl100km             625 non-null    float64
#  76  Android_device_Battery_Level                      703 non-null    int64
#  77  Litres_Per_100_KilometerLong_Term_Averagel100km   703 non-null    float64
#  78  Voltage_Control_ModuleV                           701 non-null    float64
#  79  Gz                                                703 non-null    float64
# dtypes: float64(71), int64(4), object(5)
# memory usage: 439.5+ KB
